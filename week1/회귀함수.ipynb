# %%
import io
import pandas as pd

data = pd.read_csv(io.StringIO('''
1.805204579,-0.8811019498
7.571074113,5.387225985
0.9642882978,0.5901447453
4.997130013,2.942112237
3.331671862,8.33491152
3.998603067,10.26311668
5.4634442,2.2629379
0.4951485043,4.392162058
1.602891775,0.2943116553
6.070169089,10.60924472
3.759625035,9.81702812
1.398794243,1.356956256
5.928701377,8.09806124
8.708318568,2.525776352
3.248394405,13.07787521
6.666429619,23.10203806
9.653472427,32.25536792
1.74048082,2.458725024
4.304523141,8.74740474
8.65417685,2.622236263
1.053997577,6.079482873
9.642959872,30.23239839
9.893528629,25.43330227
4.739033975,-1.980310838
0.8181986251,4.385119816
9.170448732,16.73522506
0.1015859818,-3.866853089
6.411406533,21.04522846
5.516578802,6.418061069
7.654573512,8.937492474
9.633438586,30.30237671
8.0785699,5.224242238
0.7068647832,4.66700904
3.749120514,14.55735112
5.712690727,6.851156209
8.220972226,-0.9335997267
4.353294887,8.268371746
6.706229084,21.71115907
1.016137448,-0.109746012
6.256171531,10.91137968
1.095524935,6.292441122
9.886987687,28.79928001
1.283549617,3.323987177
9.490597693,20.80802145
0.5681422143,3.720551671
9.141498538,14.27672817
0.06659770109,1.761350789
5.877215152,3.854083054
8.450291881,-4.255861028
6.937625245,20.10153208
3.715365204,6.25850562
9.947560771,28.62920172
7.215935577,18.69426316
8.674273345,1.936933484
8.148165317,2.778089489
1.249509374,3.258618828
4.658776402,4.782581924
8.484200054,-2.80485951
5.210143341,3.588198834
6.89752387,24.2604971
2.181905416,0.2793187056
8.012980462,6.225373647
0.498411419,4.301790924
2.430027916,5.240461196
1.570731027,-3.340967577
3.154910964,5.349004264
6.416225925,18.41588941
8.068933123,4.406317651
8.508779377,-0.8404316012
0.5332595391,-1.537862028
'''), header=None)

# %%
import matplotlib.pyplot as plt

x = data[0].tolist()
y = data[1].tolist()

plt.scatter(x, y)
plt.show()

# %%
import numpy as np

order = 30  # 몇차 함수 사용할지에 대한 숫자
mymodel = np.poly1d(np.polyfit(x, y, order))  # 회귀 문제를 알아서 풀어줌!
print(mymodel)

# 우리가 찾은 모델을 그려보자
myline = np.linspace(0, 10, 100)
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()
# Out:
#             30             29            28             27
# -1.476e-19 x  + 7.996e-18 x  - 1.46e-16 x  + 5.616e-16 x
#               26             25            24             23
#  + 1.069e-14 x  - 4.019e-14 x  - 1.09e-12 x  - 5.715e-13 x
#               22            21             20             19
#  + 1.023e-10 x  + 5.81e-10 x  - 7.141e-09 x  - 9.514e-08 x
#               18             17            16            15
#  + 2.754e-07 x  + 1.095e-05 x  + 8.05e-06 x  - 0.001131 x
#              14          13         12         11         10         9
#  - 0.001771 x  + 0.1226 x  - 0.221 x  - 11.94 x  + 146.2 x  - 909.2 x
#          8        7             6             5             4
#  + 3621 x - 9851 x + 1.863e+04 x - 2.432e+04 x + 2.133e+04 x
#               3        2
#  - 1.196e+04 x + 3922 x - 622.4 x + 29.15
# <ipython-input-59-2d6352e567d8>:4: RankWarning: Polyfit may be poorly conditioned
#   mymodel = np.poly1d(np.polyfit(x, y, order))  # 회귀 문제를 알아서 풀어줌!

# %%
x = np.array([9.711307073, 0.7956544127,1.866425874,6.070416584,0.04306186361,7.127298511,
             8.474656913,2.712239848,4.982193571,6.008536341,7.157298671,8.680544956,6.631189149,5.879336292,6.616682719,
             1.146765466,3.427339736,2.568570141,6.337365982,4.237250255])
y = np.array([22.42261415,4.591308825,6.732851747,15.14083317,3.086123727,17.25459702,19.94931383,8.424479695,12.96438714,15.01707268,
              17.31459734,20.36108991,16.2623783,14.75867258,16.23336544,5.293530932,9.854679472,8.137140282,15.67473196,11.47450051])
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(x, y, random_state=42)
train_input = train_input.reshape(-1, 1)
test_input = test_input.reshape(-1, 1)

from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor(n_neighbors=3)
knr.fit(train_input, train_target)

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_input, train_target)

plt.scatter(train_input, train_target)
plt.plot([min(x), max(x)], [min(x)*lr.coef_+lr.intercept_, max(x)*lr.coef_+lr.intercept_])

# %%
x = np.array([2.254235614,7.502592373,2.7133517,9.774520461,6.868457725,7.998949532,6.82279956,5.080419862,6.320125937,5.641808831,
              9.647420926,4.833828725,6.818462161,8.984591741,3.473591965, 3.39087317432163, 9.340974918,9.907476389,9.578590379,0.1375056881])
y = np.array([1.378475153,19.54178666,4.356272581,26.5716189,14.60446541,20.57696067,17.63283101,11.21315166,13.81481571,9.934975248,
              25.98258652,11.36386745,16.48987672,22.7417226,7.707193976,4.526956387,21.78839736,25.58939317,23.96109,-6.699647042])
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(x, y, random_state=42)
train_input = train_input.reshape(-1, 1)
test_input = test_input.reshape(-1, 1)

from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor(n_neighbors=3)
knr.fit(train_input, train_target)

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_input, train_target)

plt.scatter(train_input, train_target)
plt.plot([min(x), max(x)], [min(x)*lr.coef_+lr.intercept_, max(x)*lr.coef_+lr.intercept_])

# %%
import numpy as np
x = np.array([0.3677471741,4.2733599,8.387553189,1.391683427,2.733872382,6.534866539,0.1752605833,2.247364631,5.462769513,2.759016937,
              4.310732048,7.6790348,7.6245414,2.368853821,5.835081626,0.9767078323,2.65940286,3.851685941,1.119541716,1.351089319])
y = np.array([23.9495801,-0.7938753154,39.89007558,11.76299792,2.037518095,14.08768615,27.29737539,7.426860328,5.770617785,0.007987287039,
              -2.081891787,23.88869595,24.93691355,4.005807031,3.353638038,19.71096175,2.736772067,-3.312738236,15.04988716,12.4071713])
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(x, y, random_state=42)
train_input = train_input.reshape(-1, 1)
test_input = test_input.reshape(-1, 1)

from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor(n_neighbors=3)
knr.fit(train_input, train_target)

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_input, train_target)

import matplotlib.pyplot as plt
plt.scatter(train_input, train_target)
plt.plot([min(x), max(x)], [min(x)*lr.coef_+lr.intercept_, max(x)*lr.coef_+lr.intercept_])
